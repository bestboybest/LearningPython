# %% [markdown]
# # GDP Of Countries Dataset Analysis
#
# We will be using the pandas library to analyse the given dataset of GDP of countries in the time period 2020-2025. We will be doing **Exploratory Data Analysis** (*EDA*), in which we will try to uncover various patterns/find anomalies in the dataset by analysis and visualizations.
#
# The given data is in terms of millions of current USD.
#
# We shall use matplotlib for the plots on this project, but will use seaborn from the next project.

# %%
#import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load and see data format
gdp = pd.read_csv('2020-2025.csv')
gdp
# Out:
#          Country    2020      2021      2022      2023      2024      2025
# 0    Afghanistan   20136   14278.0   14501.0   17248.0       NaN       NaN
# 1        Albania   15271   18086.0   19185.0   23388.0   27259.0   28372.0
# 2        Algeria  164774  185850.0  225709.0  247789.0  264913.0  268885.0
# 3        Andorra    2885    3325.0    3376.0    3786.0    4038.0    4035.0
# 4         Angola   66521   84375.0  142442.0  109764.0  115946.0  113343.0
# ..           ...     ...       ...       ...       ...       ...       ...
# 191      Vietnam  346310  370076.0  411068.0  433008.0  459472.0  490970.0
# 192    Palestine   15532   18109.0   19166.0   17848.0       NaN       NaN
# 193        Yemen   20220   19394.0   23534.0   19412.0   19101.0   17401.0
# 194       Zambia   18138   22096.0   29164.0   27578.0   26326.0   28910.0
# 195     Zimbabwe   26878   36016.0   32613.0   35144.0   35224.0   38172.0
#
# [196 rows x 7 columns]

# %% [markdown]
# #### Analysing richest and poorest countries (Considering overall GDP over the 5 years)

# %%
#Creating new array sorted based on total GDP over the 5 years

gdpSorted = gdp.copy()
gdpSorted['Total'] = gdp.loc[:, '2020':'2025'].sum(axis = 1)
gdpSorted = gdpSorted.sort_values('Total', ascending = False).reset_index(drop = True)

gdpSorted
# Out:
#               Country      2020        2021        2022        2023  \
# 0       United States  21354125  23681175.0  26006900.0  27720725.0
# 1               China  15103357  18190803.0  18307816.0  18270351.0
# 2               Japan   5054069   5039148.0   4262146.0   4213167.0
# 3             Germany   3936989   4351188.0   4166872.0   4527009.0
# 4               India   2674852   3167271.0   3346107.0   3638490.0
# ..                ...       ...         ...         ...         ...
# 191          Kiribati       222       285.0       271.0       289.0
# 192             Palau       259       236.0       248.0       275.0
# 193  Marshall Islands       242       259.0       253.0       259.0
# 194             Nauru       125       176.0       152.0       152.0
# 195            Tuvalu        52        62.0        61.0        63.0
#
#            2024        2025        Total
# 0    29184900.0  30507217.0  158455042.0
# 1    18748009.0  19231705.0  107852041.0
# 2     4026211.0   4186431.0   26781172.0
# 3     4658526.0   4744804.0   26385388.0
# 4     3909097.0   4187017.0   20922834.0
# ..          ...         ...          ...
# 191       308.0       312.0       1687.0
# 192       306.0       333.0       1657.0
# 193       280.0       297.0       1590.0
# 194       161.0       169.0        935.0
# 195        65.0        65.0        368.0
#
# [196 rows x 8 columns]

# %%
# Getting top 10 and bottom 10 countries for anaylsis via visualization

top10 = gdpSorted.loc[:9, :]
bottom10 = gdpSorted.tail(10).sort_values('Total').reset_index(drop = True)

plt.figure(figsize = (12, 12), dpi = 100)
plt.subplot(2, 1, 1)
plt.bar(top10['Country'], top10['Total']/(10**6), color = 'green')
plt.title("GDP of the 10 richest countries over the last 6 years", fontdict = {'weight': 'bold', 'size': 20, 'name' : 'Comic Sans MS'})
plt.xlabel('Countries', size = 16)
plt.ylabel('Total GDP (Current USD in Trillions)', size = 16)
plt.grid(axis = 'y', linestyle = '--', alpha = 0.4)

plt.subplot(2, 1, 2)
plt.bar(bottom10['Country'], bottom10['Total'], color = 'red')
plt.title("GDP of the 10 poorest countries over the last 6 years", fontdict = {'weight': 'bold', 'size': 20, 'name' : 'Comic Sans MS'})
plt.xlabel('Countries', size = 16)
plt.ylabel('Total GDP (Current USD in Millions)', size = 16)
plt.xticks(rotation=30, ha='right')
plt.grid(axis = 'y', linestyle = '--', alpha = 0.4)

plt.tight_layout()
plt.savefig('GDPRichestPoorest.png', dpi = 300)
plt.show()

# %% [markdown]
# That was our analysis of the GDP of the top 10 and lowest 10 countries in terms of their GDP over the last 6 years, along with a visualization.
